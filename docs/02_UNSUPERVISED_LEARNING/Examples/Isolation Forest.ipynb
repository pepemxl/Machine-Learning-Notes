# %%
PATH ="../../data/"
filename = "data_homes.csv"

# %%
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.inspection import DecisionBoundaryDisplay

import pandas as pd
import numpy as np
import os

# %%
full_filename = os.path.join(PATH, filename)

# %%
df = pd.read_csv(full_filename)

# %%
features = ['beds','bath', 'price', 'year_built', 'sqft', 'price_per_sqft', 'elevation']
labels = ['in_sf']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df[features], df[labels], random_state=1984)

# %%
model = IsolationForest(
    n_estimators=10, 
    max_samples='auto', 
    contamination=float(0.1),
    max_features=len(features))

model.fit(df[features])
# Out:
# /home/pepe/miniconda3/envs/ML39/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.1, max_features=7, n_estimators=10)

# %%
df['scores'] = model.decision_function(df[features])
df['anomaly'] = model.predict(df[features])

# %%
df.sort_values(by='scores', ascending=True).head(10)
# Out:
#      in_sf  beds  bath     price  year_built  sqft  price_per_sqft  elevation  \
# 139      0   7.0   7.0  19500000        1994  4238            4601         10
# 109      0   5.0   5.0  27500000        1930  7500            3667         21
# 343      1   4.0   4.5   5200000        1952  4813            1080        238
# 137      0   5.0   5.0  19000000        2016  4972            3821         15
# 120      0   5.0   5.0  19000000        2016  4972            3821         10
# 123      0  10.0  10.0   7995000        1910  6400            1249         12
# 151      0   4.0   5.0  12000000        1939  3700            3243         22
# 117      0   3.0   3.0  14950000        1931  4435            3371         10
# 360      1   5.0   5.0   2990000        2014  5000             598        108
# 402      1   4.0   3.5   9895000        2008  6024            1643         62
#
#        scores  anomaly
# 139 -0.261238       -1
# 109 -0.229844       -1
# 343 -0.156715       -1
# 137 -0.148662       -1
# 120 -0.148662       -1
# 123 -0.138435       -1
# 151 -0.135257       -1
# 117 -0.126239       -1
# 360 -0.124942       -1
# 402 -0.116271       -1

# %%
print("Percentage of anomalies: {0}".format(round(df[df['anomaly']==-1].shape[0]/df.shape[0],2)))
# Out:
# Percentage of anomalies: 0.1

# %%
df.shape
# Out:
# (492, 10)

# %%
model.estimators_
# Out:
# [ExtraTreeRegressor(max_depth=8, max_features=1, random_state=126051491),
#  ExtraTreeRegressor(max_depth=8, max_features=1, random_state=1746075614),
#  ExtraTreeRegressor(max_depth=8, max_features=1, random_state=846597341),
#  ExtraTreeRegressor(max_depth=8, max_features=1, random_state=1822848662),
#  ExtraTreeRegressor(max_depth=8, max_features=1, random_state=1300756416),
#  ExtraTreeRegressor(max_depth=8, max_features=1, random_state=620757409),
#  ExtraTreeRegressor(max_depth=8, max_features=1, random_state=294522279),
#  ExtraTreeRegressor(max_depth=8, max_features=1, random_state=18685554),
#  ExtraTreeRegressor(max_depth=8, max_features=1, random_state=552638662),
#  ExtraTreeRegressor(max_depth=8, max_features=1, random_state=1222538470)]

# %%
outliers_counter = df[df['price'] > 6000000].shape[0]
outliers_counter
# Out:
# 28

# %%
filtered = df[df['anomaly']==-1]
anomalies_outliter_counter = filtered[filtered['price'] > 6000000].shape[0]
anomalies_outliter_counter
# Out:
# 28

# %%
print("Percentage of anomalies being outliers respect price {0}%".format(round(anomalies_outliter_counter/outliers_counter*100,2)))
# Out:
# Percentage of anomalies being outliers respect price 100.0%

# %%
fn=list(df[features].columns)
cn='anomaly'

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=200)
tree.plot_tree(model.estimators_[0],
               feature_names = fn,
               class_names = 'anomaly',
               filled = True)
# Out:
# [Text(0.6204656862745098, 0.9444444444444444, 'beds <= 2.648\nsquared_error = 0.078\nsamples = 256\nvalue = 0.477'),
#  Text(0.3590686274509804, 0.8333333333333334, 'bath <= 1.416\nsquared_error = 0.076\nsamples = 178\nvalue = 0.492'),
#  Text(0.22647058823529412, 0.7222222222222222, 'sqft <= 695.995\nsquared_error = 0.076\nsamples = 109\nvalue = 0.49'),
#  Text(0.12745098039215685, 0.6111111111111112, 'sqft <= 577.332\nsquared_error = 0.067\nsamples = 33\nvalue = 0.51'),
#  Text(0.07058823529411765, 0.5, 'price <= 660827.162\nsquared_error = 0.054\nsamples = 18\nvalue = 0.523'),
#  Text(0.0392156862745098, 0.3888888888888889, 'price_per_sqft <= 1174.518\nsquared_error = 0.044\nsamples = 13\nvalue = 0.534'),
#  Text(0.023529411764705882, 0.2777777777777778, 'beds <= 0.711\nsquared_error = 0.042\nsamples = 9\nvalue = 0.469'),
#  Text(0.01568627450980392, 0.16666666666666666, 'year_built <= 1903.576\nsquared_error = 0.035\nsamples = 8\nvalue = 0.433'),
#  Text(0.00784313725490196, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.298'),
#  Text(0.023529411764705882, 0.05555555555555555, 'squared_error = 0.037\nsamples = 7\nvalue = 0.452'),
#  Text(0.03137254901960784, 0.16666666666666666, 'squared_error = -0.0\nsamples = 1\nvalue = 0.762'),
#  Text(0.054901960784313725, 0.2777777777777778, 'price <= 593051.406\nsquared_error = 0.019\nsamples = 4\nvalue = 0.679'),
#  Text(0.047058823529411764, 0.16666666666666666, 'beds <= 0.696\nsquared_error = 0.024\nsamples = 3\nvalue = 0.69'),
#  Text(0.0392156862745098, 0.05555555555555555, 'squared_error = 0.006\nsamples = 2\nvalue = 0.791'),
#  Text(0.054901960784313725, 0.05555555555555555, 'squared_error = -0.0\nsamples = 1\nvalue = 0.487'),
#  Text(0.06274509803921569, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.648'),
#  Text(0.10196078431372549, 0.3888888888888889, 'sqft <= 537.688\nsquared_error = 0.079\nsamples = 5\nvalue = 0.496'),
#  Text(0.08627450980392157, 0.2777777777777778, 'sqft <= 528.358\nsquared_error = 0.085\nsamples = 2\nvalue = 0.575'),
#  Text(0.0784313725490196, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.284'),
#  Text(0.09411764705882353, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.866'),
#  Text(0.11764705882352941, 0.2777777777777778, 'price <= 775274.255\nsquared_error = 0.068\nsamples = 3\nvalue = 0.443'),
#  Text(0.10980392156862745, 0.16666666666666666, 'sqft <= 551.933\nsquared_error = 0.0\nsamples = 2\nvalue = 0.259'),
#  Text(0.10196078431372549, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.257'),
#  Text(0.11764705882352941, 0.05555555555555555, 'squared_error = -0.0\nsamples = 1\nvalue = 0.261'),
#  Text(0.12549019607843137, 0.16666666666666666, 'squared_error = -0.0\nsamples = 1\nvalue = 0.811'),
#  Text(0.1843137254901961, 0.5, 'elevation <= 49.45\nsquared_error = 0.082\nsamples = 15\nvalue = 0.493'),
#  Text(0.1568627450980392, 0.3888888888888889, 'elevation <= 36.034\nsquared_error = 0.088\nsamples = 8\nvalue = 0.577'),
#  Text(0.14901960784313725, 0.2777777777777778, 'elevation <= 11.578\nsquared_error = 0.101\nsamples = 7\nvalue = 0.577'),
#  Text(0.1411764705882353, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.955'),
#  Text(0.1568627450980392, 0.16666666666666666, 'year_built <= 1973.184\nsquared_error = 0.09\nsamples = 6\nvalue = 0.513'),
#  Text(0.14901960784313725, 0.05555555555555555, 'squared_error = 0.041\nsamples = 4\nvalue = 0.545'),
#  Text(0.16470588235294117, 0.05555555555555555, 'squared_error = 0.181\nsamples = 2\nvalue = 0.45'),
#  Text(0.16470588235294117, 0.2777777777777778, 'squared_error = -0.0\nsamples = 1\nvalue = 0.583'),
#  Text(0.21176470588235294, 0.3888888888888889, 'price_per_sqft <= 1355.294\nsquared_error = 0.058\nsamples = 7\nvalue = 0.396'),
#  Text(0.20392156862745098, 0.2777777777777778, 'sqft <= 643.268\nsquared_error = 0.039\nsamples = 6\nvalue = 0.46'),
#  Text(0.18823529411764706, 0.16666666666666666, 'sqft <= 601.91\nsquared_error = 0.033\nsamples = 3\nvalue = 0.403'),
#  Text(0.1803921568627451, 0.05555555555555555, 'squared_error = 0.015\nsamples = 2\nvalue = 0.296'),
#  Text(0.19607843137254902, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.616'),
#  Text(0.2196078431372549, 0.16666666666666666, 'price_per_sqft <= 660.936\nsquared_error = 0.038\nsamples = 3\nvalue = 0.518'),
#  Text(0.21176470588235294, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.375'),
#  Text(0.22745098039215686, 0.05555555555555555, 'squared_error = 0.041\nsamples = 2\nvalue = 0.59'),
#  Text(0.2196078431372549, 0.2777777777777778, 'squared_error = -0.0\nsamples = 1\nvalue = 0.01'),
#  Text(0.3254901960784314, 0.6111111111111112, 'price <= 721025.422\nsquared_error = 0.079\nsamples = 76\nvalue = 0.482'),
#  Text(0.27058823529411763, 0.5, 'elevation <= 167.702\nsquared_error = 0.071\nsamples = 28\nvalue = 0.429'),
#  Text(0.2627450980392157, 0.3888888888888889, 'price <= 413058.569\nsquared_error = 0.067\nsamples = 27\nvalue = 0.444'),
#  Text(0.24313725490196078, 0.2777777777777778, 'elevation <= 30.677\nsquared_error = 0.037\nsamples = 3\nvalue = 0.344'),
#  Text(0.23529411764705882, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.353'),
#  Text(0.25098039215686274, 0.16666666666666666, 'squared_error = 0.056\nsamples = 2\nvalue = 0.339'),
#  Text(0.2823529411764706, 0.2777777777777778, 'sqft <= 1094.36\nsquared_error = 0.069\nsamples = 24\nvalue = 0.457'),
#  Text(0.26666666666666666, 0.16666666666666666, 'price_per_sqft <= 612.486\nsquared_error = 0.046\nsamples = 18\nvalue = 0.443'),
#  Text(0.25882352941176473, 0.05555555555555555, 'squared_error = 0.045\nsamples = 4\nvalue = 0.553'),
#  Text(0.27450980392156865, 0.05555555555555555, 'squared_error = 0.041\nsamples = 14\nvalue = 0.412'),
#  Text(0.2980392156862745, 0.16666666666666666, 'price_per_sqft <= 500.632\nsquared_error = 0.138\nsamples = 6\nvalue = 0.498'),
#  Text(0.2901960784313726, 0.05555555555555555, 'squared_error = 0.114\nsamples = 3\nvalue = 0.584'),
#  Text(0.3058823529411765, 0.05555555555555555, 'squared_error = 0.147\nsamples = 3\nvalue = 0.411'),
#  Text(0.2784313725490196, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 0.012'),
#  Text(0.3803921568627451, 0.5, 'sqft <= 1675.905\nsquared_error = 0.081\nsamples = 48\nvalue = 0.512'),
#  Text(0.37254901960784315, 0.3888888888888889, 'year_built <= 1992.316\nsquared_error = 0.079\nsamples = 47\nvalue = 0.503'),
#  Text(0.34509803921568627, 0.2777777777777778, 'price <= 1775937.422\nsquared_error = 0.081\nsamples = 34\nvalue = 0.504'),
#  Text(0.32941176470588235, 0.16666666666666666, 'elevation <= 57.345\nsquared_error = 0.083\nsamples = 32\nvalue = 0.518'),
#  Text(0.3215686274509804, 0.05555555555555555, 'squared_error = 0.086\nsamples = 24\nvalue = 0.541'),
#  Text(0.33725490196078434, 0.05555555555555555, 'squared_error = 0.067\nsamples = 8\nvalue = 0.449'),
#  Text(0.3607843137254902, 0.16666666666666666, 'price_per_sqft <= 1886.308\nsquared_error = 0.001\nsamples = 2\nvalue = 0.287'),
#  Text(0.35294117647058826, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.25'),
#  Text(0.3686274509803922, 0.05555555555555555, 'squared_error = -0.0\nsamples = 1\nvalue = 0.324'),
#  Text(0.4, 0.2777777777777778, 'price <= 2460233.667\nsquared_error = 0.073\nsamples = 13\nvalue = 0.499'),
#  Text(0.39215686274509803, 0.16666666666666666, 'price <= 1303194.085\nsquared_error = 0.069\nsamples = 12\nvalue = 0.527'),
#  Text(0.3843137254901961, 0.05555555555555555, 'squared_error = 0.049\nsamples = 9\nvalue = 0.561'),
#  Text(0.4, 0.05555555555555555, 'squared_error = 0.112\nsamples = 3\nvalue = 0.423'),
#  Text(0.40784313725490196, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.166'),
#  Text(0.38823529411764707, 0.3888888888888889, 'squared_error = -0.0\nsamples = 1\nvalue = 0.957'),
#  Text(0.49166666666666664, 0.7222222222222222, 'bath <= 1.701\nsquared_error = 0.077\nsamples = 69\nvalue = 0.495'),
#  Text(0.42745098039215684, 0.6111111111111112, 'price_per_sqft <= 811.559\nsquared_error = 0.027\nsamples = 6\nvalue = 0.641'),
#  Text(0.4117647058823529, 0.5, 'elevation <= 46.131\nsquared_error = 0.021\nsamples = 2\nvalue = 0.557'),
#  Text(0.403921568627451, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 0.41'),
#  Text(0.4196078431372549, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 0.703'),
#  Text(0.44313725490196076, 0.5, 'elevation <= 7.125\nsquared_error = 0.025\nsamples = 4\nvalue = 0.683'),
#  Text(0.43529411764705883, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 0.653'),
#  Text(0.45098039215686275, 0.3888888888888889, 'price <= 1149750.426\nsquared_error = 0.033\nsamples = 3\nvalue = 0.692'),
#  Text(0.44313725490196076, 0.2777777777777778, 'squared_error = 0.0\nsamples = 1\nvalue = 0.633'),
#  Text(0.4588235294117647, 0.2777777777777778, 'elevation <= 13.687\nsquared_error = 0.046\nsamples = 2\nvalue = 0.722'),
#  Text(0.45098039215686275, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.937'),
#  Text(0.4666666666666667, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.506'),
#  Text(0.5558823529411765, 0.6111111111111112, 'elevation <= 64.77\nsquared_error = 0.08\nsamples = 63\nvalue = 0.481'),
#  Text(0.5196078431372549, 0.5, 'beds <= 1.201\nsquared_error = 0.082\nsamples = 60\nvalue = 0.487'),
#  Text(0.4980392156862745, 0.3888888888888889, 'elevation <= 15.148\nsquared_error = 0.049\nsamples = 4\nvalue = 0.686'),
#  Text(0.49019607843137253, 0.2777777777777778, 'price <= 1316083.484\nsquared_error = 0.039\nsamples = 3\nvalue = 0.605'),
#  Text(0.4823529411764706, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.325'),
#  Text(0.4980392156862745, 0.16666666666666666, 'price <= 1908094.442\nsquared_error = 0.0\nsamples = 2\nvalue = 0.745'),
#  Text(0.49019607843137253, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.733'),
#  Text(0.5058823529411764, 0.05555555555555555, 'squared_error = -0.0\nsamples = 1\nvalue = 0.758'),
#  Text(0.5058823529411764, 0.2777777777777778, 'squared_error = 0.0\nsamples = 1\nvalue = 0.928'),
#  Text(0.5411764705882353, 0.3888888888888889, 'sqft <= 827.416\nsquared_error = 0.081\nsamples = 56\nvalue = 0.473'),
#  Text(0.5215686274509804, 0.2777777777777778, 'sqft <= 802.146\nsquared_error = 0.037\nsamples = 2\nvalue = 0.346'),
#  Text(0.5137254901960784, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.154'),
#  Text(0.5294117647058824, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.538'),
#  Text(0.5607843137254902, 0.2777777777777778, 'price_per_sqft <= 1015.171\nsquared_error = 0.082\nsamples = 54\nvalue = 0.478'),
#  Text(0.5450980392156862, 0.16666666666666666, 'sqft <= 1262.128\nsquared_error = 0.084\nsamples = 12\nvalue = 0.506'),
#  Text(0.5372549019607843, 0.05555555555555555, 'squared_error = 0.085\nsamples = 7\nvalue = 0.592'),
#  Text(0.5529411764705883, 0.05555555555555555, 'squared_error = 0.057\nsamples = 5\nvalue = 0.385'),
#  Text(0.5764705882352941, 0.16666666666666666, 'sqft <= 1060.106\nsquared_error = 0.081\nsamples = 42\nvalue = 0.469'),
#  Text(0.5686274509803921, 0.05555555555555555, 'squared_error = 0.045\nsamples = 5\nvalue = 0.569'),
#  Text(0.5843137254901961, 0.05555555555555555, 'squared_error = 0.084\nsamples = 37\nvalue = 0.456'),
#  Text(0.592156862745098, 0.5, 'price <= 3339981.809\nsquared_error = 0.025\nsamples = 3\nvalue = 0.354'),
#  Text(0.5843137254901961, 0.3888888888888889, 'year_built <= 1923.377\nsquared_error = 0.033\nsamples = 2\nvalue = 0.313'),
#  Text(0.5764705882352941, 0.2777777777777778, 'squared_error = 0.0\nsamples = 1\nvalue = 0.133'),
#  Text(0.592156862745098, 0.2777777777777778, 'squared_error = -0.0\nsamples = 1\nvalue = 0.494'),
#  Text(0.6, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 0.435'),
#  Text(0.8818627450980392, 0.8333333333333334, 'price_per_sqft <= 1551.131\nsquared_error = 0.081\nsamples = 78\nvalue = 0.442'),
#  Text(0.8068627450980392, 0.7222222222222222, 'price_per_sqft <= 1020.923\nsquared_error = 0.086\nsamples = 68\nvalue = 0.461'),
#  Text(0.7470588235294118, 0.6111111111111112, 'beds <= 5.224\nsquared_error = 0.091\nsamples = 57\nvalue = 0.466'),
#  Text(0.6980392156862745, 0.5, 'elevation <= 140.695\nsquared_error = 0.083\nsamples = 52\nvalue = 0.446'),
#  Text(0.6549019607843137, 0.3888888888888889, 'bath <= 3.799\nsquared_error = 0.086\nsamples = 45\nvalue = 0.437'),
#  Text(0.6235294117647059, 0.2777777777777778, 'elevation <= 91.598\nsquared_error = 0.091\nsamples = 40\nvalue = 0.438'),
#  Text(0.6078431372549019, 0.16666666666666666, 'elevation <= 37.364\nsquared_error = 0.082\nsamples = 30\nvalue = 0.457'),
#  Text(0.6, 0.05555555555555555, 'squared_error = 0.098\nsamples = 12\nvalue = 0.486'),
#  Text(0.615686274509804, 0.05555555555555555, 'squared_error = 0.071\nsamples = 18\nvalue = 0.439'),
#  Text(0.6392156862745098, 0.16666666666666666, 'beds <= 3.665\nsquared_error = 0.113\nsamples = 10\nvalue = 0.382'),
#  Text(0.6313725490196078, 0.05555555555555555, 'squared_error = 0.111\nsamples = 7\nvalue = 0.503'),
#  Text(0.6470588235294118, 0.05555555555555555, 'squared_error = 0.004\nsamples = 3\nvalue = 0.099'),
#  Text(0.6862745098039216, 0.2777777777777778, 'price_per_sqft <= 651.236\nsquared_error = 0.046\nsamples = 5\nvalue = 0.422'),
#  Text(0.6705882352941176, 0.16666666666666666, 'elevation <= 8.2\nsquared_error = 0.005\nsamples = 2\nvalue = 0.218'),
#  Text(0.6627450980392157, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.288'),
#  Text(0.6784313725490196, 0.05555555555555555, 'squared_error = -0.0\nsamples = 1\nvalue = 0.147'),
#  Text(0.7019607843137254, 0.16666666666666666, 'beds <= 4.948\nsquared_error = 0.027\nsamples = 3\nvalue = 0.559'),
#  Text(0.6941176470588235, 0.05555555555555555, 'squared_error = 0.001\nsamples = 2\nvalue = 0.674'),
#  Text(0.7098039215686275, 0.05555555555555555, 'squared_error = -0.0\nsamples = 1\nvalue = 0.329'),
#  Text(0.7411764705882353, 0.3888888888888889, 'price_per_sqft <= 624.497\nsquared_error = 0.057\nsamples = 7\nvalue = 0.503'),
#  Text(0.7254901960784313, 0.2777777777777778, 'elevation <= 165.274\nsquared_error = 0.0\nsamples = 2\nvalue = 0.541'),
#  Text(0.7176470588235294, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.54'),
#  Text(0.7333333333333333, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.542'),
#  Text(0.7568627450980392, 0.2777777777777778, 'year_built <= 1935.016\nsquared_error = 0.079\nsamples = 5\nvalue = 0.488'),
#  Text(0.7490196078431373, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.873'),
#  Text(0.7647058823529411, 0.16666666666666666, 'bath <= 2.799\nsquared_error = 0.052\nsamples = 4\nvalue = 0.392'),
#  Text(0.7568627450980392, 0.05555555555555555, 'squared_error = 0.064\nsamples = 3\nvalue = 0.429'),
#  Text(0.7725490196078432, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.281'),
#  Text(0.796078431372549, 0.5, 'price_per_sqft <= 563.25\nsquared_error = 0.128\nsamples = 5\nvalue = 0.681'),
#  Text(0.7803921568627451, 0.3888888888888889, 'year_built <= 1916.506\nsquared_error = 0.145\nsamples = 2\nvalue = 0.587'),
#  Text(0.7725490196078432, 0.2777777777777778, 'squared_error = 0.0\nsamples = 1\nvalue = 0.967'),
#  Text(0.788235294117647, 0.2777777777777778, 'squared_error = 0.0\nsamples = 1\nvalue = 0.206'),
#  Text(0.8117647058823529, 0.3888888888888889, 'price_per_sqft <= 747.132\nsquared_error = 0.107\nsamples = 3\nvalue = 0.744'),
#  Text(0.803921568627451, 0.2777777777777778, 'sqft <= 2362.111\nsquared_error = 0.116\nsamples = 2\nvalue = 0.622'),
#  Text(0.796078431372549, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.281'),
#  Text(0.8117647058823529, 0.16666666666666666, 'squared_error = -0.0\nsamples = 1\nvalue = 0.963'),
#  Text(0.8196078431372549, 0.2777777777777778, 'squared_error = -0.0\nsamples = 1\nvalue = 0.988'),
#  Text(0.8666666666666667, 0.6111111111111112, 'year_built <= 2008.303\nsquared_error = 0.056\nsamples = 11\nvalue = 0.434'),
#  Text(0.8588235294117647, 0.5, 'beds <= 8.952\nsquared_error = 0.046\nsamples = 10\nvalue = 0.397'),
#  Text(0.8509803921568627, 0.3888888888888889, 'sqft <= 2161.505\nsquared_error = 0.051\nsamples = 9\nvalue = 0.406'),
#  Text(0.8352941176470589, 0.2777777777777778, 'bath <= 2.107\nsquared_error = 0.088\nsamples = 5\nvalue = 0.44'),
#  Text(0.8274509803921568, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.926'),
#  Text(0.8431372549019608, 0.16666666666666666, 'price_per_sqft <= 1214.748\nsquared_error = 0.036\nsamples = 4\nvalue = 0.318'),
#  Text(0.8352941176470589, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.482'),
#  Text(0.8509803921568627, 0.05555555555555555, 'squared_error = 0.036\nsamples = 3\nvalue = 0.264'),
#  Text(0.8666666666666667, 0.2777777777777778, 'price_per_sqft <= 1127.736\nsquared_error = 0.001\nsamples = 4\nvalue = 0.363'),
#  Text(0.8588235294117647, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.392'),
#  Text(0.8745098039215686, 0.16666666666666666, 'beds <= 4.219\nsquared_error = 0.001\nsamples = 3\nvalue = 0.353'),
#  Text(0.8666666666666667, 0.05555555555555555, 'squared_error = 0.002\nsamples = 2\nvalue = 0.356'),
#  Text(0.8823529411764706, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.347'),
#  Text(0.8666666666666667, 0.3888888888888889, 'squared_error = -0.0\nsamples = 1\nvalue = 0.319'),
#  Text(0.8745098039215686, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 0.802'),
#  Text(0.9568627450980393, 0.7222222222222222, 'bath <= 3.757\nsquared_error = 0.034\nsamples = 10\nvalue = 0.311'),
#  Text(0.9294117647058824, 0.6111111111111112, 'sqft <= 3000.294\nsquared_error = 0.012\nsamples = 6\nvalue = 0.198'),
#  Text(0.9137254901960784, 0.5, 'price_per_sqft <= 2994.678\nsquared_error = 0.005\nsamples = 4\nvalue = 0.261'),
#  Text(0.9058823529411765, 0.3888888888888889, 'price_per_sqft <= 2542.591\nsquared_error = 0.007\nsamples = 3\nvalue = 0.262'),
#  Text(0.8980392156862745, 0.2777777777777778, 'sqft <= 2195.959\nsquared_error = 0.006\nsamples = 2\nvalue = 0.223'),
#  Text(0.8901960784313725, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.297'),
#  Text(0.9058823529411765, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.148'),
#  Text(0.9137254901960784, 0.2777777777777778, 'squared_error = -0.0\nsamples = 1\nvalue = 0.341'),
#  Text(0.9215686274509803, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 0.259'),
#  Text(0.9450980392156862, 0.5, 'elevation <= 14.55\nsquared_error = 0.002\nsamples = 2\nvalue = 0.073'),
#  Text(0.9372549019607843, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 0.114'),
#  Text(0.9529411764705882, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 0.031'),
#  Text(0.984313725490196, 0.6111111111111112, 'price <= 16502290.934\nsquared_error = 0.02\nsamples = 4\nvalue = 0.48'),
#  Text(0.9764705882352941, 0.5, 'year_built <= 1993.596\nsquared_error = 0.015\nsamples = 3\nvalue = 0.427'),
#  Text(0.9686274509803922, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 0.431'),
#  Text(0.984313725490196, 0.3888888888888889, 'bath <= 4.554\nsquared_error = 0.022\nsamples = 2\nvalue = 0.425'),
#  Text(0.9764705882352941, 0.2777777777777778, 'squared_error = 0.0\nsamples = 1\nvalue = 0.575'),
#  Text(0.9921568627450981, 0.2777777777777778, 'squared_error = 0.0\nsamples = 1\nvalue = 0.275'),
#  Text(0.9921568627450981, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.641')]

# %%
nrows = 3
ncols = 3
fig, axes = plt.subplots(nrows = nrows,ncols = ncols,figsize = (10,6), dpi=300)
for index in range(0, 9):
    row = index//ncols
    col = index%ncols
    tree.plot_tree(model.estimators_[index],
                   feature_names = fn, 
                   class_names='anomaly',
                   filled = True,
                   ax = axes[row, col]
                  )
    axes[row, col].set_title('Estimator: ' + str(index), fontsize = 11)

# %%
from dtreeviz.trees import dtreeviz

# %%
viz = dtreeviz(model.estimators_[0],
               df[features], 
               df['anomaly'], 
               target_name='anomaly', 
               orientation ='LR',  # left-right orientation
               feature_names=features,
               class_names = ['inlier','anomaly'],
               X=df[features].iloc[0],
               fancy=False
              )  # need to give single observation for prediction
              
viz.view()

# %%
# %%script echo skip
# from dtreeviz import clfviz
#
# clfviz(
#     model.estimators_[0],
#     df[features],
#     df['anomaly'],
#     feature_names=features,
#     target_name='anomaly'
# )
# Out:
# skip

# %%
# %%script echo skip
# fig,axes = plt.subplots(1,2, figsize=(8,3.8), dpi=300)
# clfviz(
#     model.estimators_[0],
#     df[features],
#     df['anomaly'],
#     ax=axes[0],
#     feature_names=['price', 'elevation']
# )
# clfviz(
#     model.estimators_[0],
#     df[features],
#     df['anomaly'],
#     ax=axes[1],
#     # show classification regions not probabilities
#     show=['instances', 'boundaries', 'misclassified'],
#     feature_names=['price', 'elevation']
# )
# plt.show()
# Out:
# skip
